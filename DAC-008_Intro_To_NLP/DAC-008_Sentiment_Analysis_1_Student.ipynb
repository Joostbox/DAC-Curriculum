# %% [markdown]
# # Sentiment Analysis 1

# %% [markdown]
# ## Table of Contents:
# Twitter Analysis of the Russian-Ukraine Crisis
#   * Data Preprocessing
#   * EDA
#   * Feature Extraction
#   * ML Model Predictions
#   * Cross Validation
#   * Evaluation

# %% [markdown]
# ### Import Libraries

# %%
# For dataframes
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# Importing all nltk related libraries
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
nltk.download('all')
nltk.download('vader_lexicon')
nltk.download('stopwords')
nltk.download('wordnet')
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from sklearn.linear_model import LogisticRegression

# Subjectivity and Polarity
from textblob import TextBlob

# Regular Expressions
import re
import string

# Bag of Words representation
import collections
from sklearn.feature_extraction.text import CountVectorizer

# Wordcloud
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

# To ignore warning
import warnings
warnings.filterwarnings("ignore")

# Emotion
# !pip install nrclex
from nrclex import NRCLex

# Mime type rendering
# !pip install nbformat
import nbformat
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to
# [nltk_data]    |     /Users/joostbox/nltk_data...
# [nltk_data]    |   Package abc is already up-to-date!
# [nltk_data]    | Downloading package alpino to
# [nltk_data]    |     /Users/joostbox/nltk_data...
# [nltk_data]    |   Package alpino is already up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /Users/joostbox/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]    |     /Users/joostbox/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger_eng is already
# [nltk_data]    |       up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     /Users/joostbox/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger_ru is already
# [nltk_data]    |       up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger_rus to
# [nltk_data]    |     /Users/joostbox/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger_rus is already
# [nltk_data]    |       up-to-date!
# [nltk_data]    | Downloading package basque_grammars to
# [nltk_data]    |     /Users/joostbox/nltk_data...
# [nltk_data]    |   Package basque_grammars is already up-to-date!
# [nltk_data]    | Downloading package bcp47 to
# [nltk_data]    |     /Users/joostbox/nltk_data...
# [nltk_data]    |   Package bcp47 is already up-to-date!
# [nltk_data]    | Downloading package biocreative_ppi to
# [nltk_data]    |     /Users/joostbox/nltk_data...
# [nltk_data]    |   Package biocreative_ppi is already up-to-date!
# [nltk_data]    | Downloading package bllip_wsj_no_aux to
# [nltk_data]    |     /Users/joostbox/nltk_data...
# [nltk_data]    |   Package bllip_wsj_no_aux is already up-to-date!
# [nltk_data]    | Downloading package book_grammars to
# [nltk_data]    |     /Users/joostbox/nltk_data...
# [nltk_data]    |   Package book_grammars is already up-to-date!
# [nltk_data]    | Downloading package brown to
# [nltk_data]    |     /Users/joostbox/nltk_data...
# [nltk_data]    |   Package brown is already up-to-date!
# [nltk_data]    | Downloading package brown_tei to
# [nltk_data]    |     /Users/joostbox/nltk_data...
# [nltk_data]    |   Package brown_tei is already up-to-date!
# [nltk_data]    | Downloading package cess_cat to
# [nltk_data]    |     /Users/joostbox/nltk_data...
# [nltk_data]    |   Package cess_cat is already up-to-date!
# [nltk_data]    | Downloading package cess_esp to
# [nltk_data]    |     /Users/joostbox/nltk_data...
# [nltk_data]    |   Package cess_esp is already up-to-date!
# [nltk_data]    | Downloading package chat80 to
# [nltk_data]    |     /Users/joostbox/nltk_data...
# [nltk_data]    |   Package chat80 is already up-to-date!
# [nltk_data]    | Downloading package city_database to
# [nltk_data]    |     /Users/joostbox/nltk_data...
# [nltk_data]    |   Package city_database is already up-to-date!
# [nltk_data]    | Downloading package cmudict to
# [nltk_data]    |     /Users/joostbox/nltk_data...
# [nltk_data]    |   Package cmudict is already up-to-date!
# [nltk_data]    | Downloading package comparative_sentences to
# [nltk_data]    |     /Users/joostbox/nltk_data...
# [nltk_data]    |   Package comparative_sentences is already up-to-
# [nltk_data]    |       date!
# [nltk_data]    | Downloading package comtrans to
# [nltk_data]    |     /Users/joostbox/nltk_data...
# [nltk_data]    |   Package comtrans is already up-to-date!
# [nltk_data]    | Downloading package conll2000 to
# [nltk_data]    |     /Users/joostbox/nltk_data...
# [nltk_data]    |   Package conll2000 is already up-to-date!
# [nltk_data]    | Downloading package conll2002 to
# [nltk_data]    |     /Users/joostbox/nltk_data...
# [nltk_data]    |   Package conll2002 is already up-to-date!
# [nltk_data]    | Downloading package conll2007 to
# [nltk_data]    |     /Users/joostbox/nltk_data...
# [nltk_data]    |   Package conll2007 is already up-to-date!
# [nltk_data]    | Downloading package crubadan to
# [nltk_data]    |     /Users/joostbox/nltk_data...
# [nltk_data]    |   Package crubadan is already up-to-date!
# [nltk_data]    | Downloading package dependency_treebank to
# [nltk_data]    |     /Users/joostbox/nltk_data...
# [nltk_data]    |   Package dependency_treebank is already up-to-date!
# [nltk_data]    | Downloading package dolch to
# [nltk_data]    |     /Users/joostbox/nltk_data...
# [nltk_data]    |   Package dolch is already up-to-date!
# [nltk_data]    | Downloading package europarl_raw to
# [nltk_data]    |     /Users/joostbox/nltk_data...
# [nltk_data]    |   Package europarl_raw is already up-to-date!
# [nltk_data]    | Downloading package extended_omw to
# [nltk_data]    |     /Users/joostbox/nltk_data...
# [nltk_data]    |   Package extended_omw is already up-to-date!
# [nltk_data]    | Downloading package floresta to
# [nltk_data]    |     /Users/joostbox/nltk_data...
# [nltk_data]    |   Package floresta is already up-to-date!
# [nltk_data]    | Downloading package framenet_v15 to
# [nltk_data]    |     /Users/joostbox/nltk_data...
# [nltk_data]    |   Package framenet_v15 is already up-to-date!
# [nltk_data]    | Downloading package framenet_v17 to
# [nltk_data]    |     /Users/joostbox/nltk_data...
# [nltk_data]    |   Package framenet_v17 is already up-to-date!
# [nltk_data]    | Downloading package gazetteers to
# [nltk_data]    |     /Users/joostbox/nltk_data...
# [nltk_data]    |   Package gazetteers is already up-to-date!
# [nltk_data]    | Downloading package genesis to
# [nltk_data]    |     /Users/joostbox/nltk_data...
# [nltk_data]    |   Package genesis is already up-to-date!
# [nltk_data]    | Downloading package gutenberg to
# [nltk_data]    |     /Users/joostbox/nltk_data...
# [nltk_data]    |   Package gutenberg is already up-to-date!
# [nltk_data]    | Downloading package ieer to
# [nltk_data]    |     /Users/joostbox/nltk_data...
# [nltk_data]    |   Package ieer is already up-to-date!
# [nltk_data]    | Downloading package inaugural to
# [nltk_data]    |     /Users/joostbox/nltk_data...
# [nltk_data]    |   Package inaugural is already up-to-date!
# [nltk_data]    | Downloading package indian to
# [nltk_data]    |     /Users/joostbox/nltk_data...
# [nltk_data]    |   Package indian is already up-to-date!
# [nltk_data]    | Downloading package jeita to
# [nltk_data]    |     /Users/joostbox/nltk_data...
# [nltk_data]    |   Package jeita is already up-to-date!
# [nltk_data]    | Downloading package kimmo to
# [nltk_data]    |     /Users/joostbox/nltk_data...
# [nltk_data]    |   Package kimmo is already up-to-date!
# [nltk_data]    | Downloading package knbc to
# [nltk_data]    |     /Users/joostbox/nltk_data...
# [nltk_data]    |   Package knbc is already up-to-date!
# [nltk_data]    | Downloading package large_grammars to
# [nltk_data]    |     /Users/joostbox/nltk_data...
# [nltk_data]    |   Package large_grammars is already up-to-date!
# [nltk_data]    | Downloading package lin_thesaurus to
# [nltk_data]    |     /Users/joostbox/nltk_data...
# [nltk_data]    |   Package lin_thesaurus is already up-to-date!
# [nltk_data]    | Downloading package mac_morpho to
# [nltk_data]    |     /Users/joostbox/nltk_data...
# [nltk_data]    |   Package mac_morpho is already up-to-date!
# [nltk_data]    | Downloading package machado to
# [nltk_data]    |     /Users/joostbox/nltk_data...
# [nltk_data]    |   Package machado is already up-to-date!
# [nltk_data]    | Downloading package masc_tagged to
# [nltk_data]    |     /Users/joostbox/nltk_data...
# [nltk_data]    |   Package masc_tagged is already up-to-date!
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     /Users/joostbox/nltk_data...
# [nltk_data]    |   Package maxent_ne_chunker is already up-to-date!
# [nltk_data]    | Downloading package maxent_ne_chunker_tab to
# [nltk_data]    |     /Users/joostbox/nltk_data...
# [nltk_data]    |   Package maxent_ne_chunker_tab is already up-to-
# [nltk_data]    |       date!
# [nltk_data]    | Downloading package maxent_treebank_pos_tagger to
# [nltk_data]    |     /Users/joostbox/nltk_data...
# [nltk_data]    |   Package maxent_treebank_pos_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    | Downloading package maxent_treebank_pos_tagger_tab to
# [nltk_data]    |     /Users/joostbox/nltk_data...
# [nltk_data]    |   Package maxent_treebank_pos_tagger_tab is already
# [nltk_data]    |       up-to-date!
# [nltk_data]    | Downloading package moses_sample to
# [nltk_data]    |     /Users/joostbox/nltk_data...
# [nltk_data]    |   Package moses_sample is already up-to-date!
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     /Users/joostbox/nltk_data...
# [nltk_data]    |   Package movie_reviews is already up-to-date!
# [nltk_data]    | Downloading package mte_teip5 to
# [nltk_data]    |     /Users/joostbox/nltk_data...
# [nltk_data]    |   Package mte_teip5 is already up-to-date!
# [nltk_data]    | Downloading package mwa_ppdb to
# [nltk_data]    |     /Users/joostbox/nltk_data...
# [nltk_data]    |   Package mwa_ppdb is already up-to-date!
# [nltk_data]    | Downloading package names to
# [nltk_data]    |     /Users/joostbox/nltk_data...
# [nltk_data]    |   Package names is already up-to-date!
# [nltk_data]    | Downloading package nombank.1.0 to
# [nltk_data]    |     /Users/joostbox/nltk_data...
# [nltk_data]    |   Package nombank.1.0 is already up-to-date!
# [nltk_data]    | Downloading package nonbreaking_prefixes to
# [nltk_data]    |     /Users/joostbox/nltk_data...
# [nltk_data]    |   Package nonbreaking_prefixes is already up-to-date!
# [nltk_data]    | Downloading package nps_chat to
# [nltk_data]    |     /Users/joostbox/nltk_data...
# [nltk_data]    |   Package nps_chat is already up-to-date!
# [nltk_data]    | Downloading package omw to
# [nltk_data]    |     /Users/joostbox/nltk_data...
# [nltk_data]    |   Package omw is already up-to-date!
# [nltk_data]    | Downloading package omw-1.4 to
# [nltk_data]    |     /Users/joostbox/nltk_data...
# [nltk_data]    |   Package omw-1.4 is already up-to-date!
# [nltk_data]    | Downloading package opinion_lexicon to
# [nltk_data]    |     /Users/joostbox/nltk_data...
# [nltk_data]    |   Package opinion_lexicon is already up-to-date!
# [nltk_data]    | Downloading package panlex_swadesh to
# [nltk_data]    |     /Users/joostbox/nltk_data...
# [nltk_data]    |   Package panlex_swadesh is already up-to-date!
# [nltk_data]    | Downloading package paradigms to
# [nltk_data]    |     /Users/joostbox/nltk_data...
# [nltk_data]    |   Package paradigms is already up-to-date!
# [nltk_data]    | Downloading package pe08 to
# [nltk_data]    |     /Users/joostbox/nltk_data...
# [nltk_data]    |   Package pe08 is already up-to-date!
# [nltk_data]    | Downloading package perluniprops to
# [nltk_data]    |     /Users/joostbox/nltk_data...
# [nltk_data]    |   Package perluniprops is already up-to-date!
# [nltk_data]    | Downloading package pil to
# [nltk_data]    |     /Users/joostbox/nltk_data...
# [nltk_data]    |   Package pil is already up-to-date!
# [nltk_data]    | Downloading package pl196x to
# [nltk_data]    |     /Users/joostbox/nltk_data...
# [nltk_data]    |   Package pl196x is already up-to-date!
# [nltk_data]    | Downloading package porter_test to
# [nltk_data]    |     /Users/joostbox/nltk_data...
# [nltk_data]    |   Package porter_test is already up-to-date!
# [nltk_data]    | Downloading package ppattach to
# [nltk_data]    |     /Users/joostbox/nltk_data...
# [nltk_data]    |   Package ppattach is already up-to-date!
# [nltk_data]    | Downloading package problem_reports to
# [nltk_data]    |     /Users/joostbox/nltk_data...
# [nltk_data]    |   Package problem_reports is already up-to-date!
# [nltk_data]    | Downloading package product_reviews_1 to
# [nltk_data]    |     /Users/joostbox/nltk_data...
# [nltk_data]    |   Package product_reviews_1 is already up-to-date!
# [nltk_data]    | Downloading package product_reviews_2 to
# [nltk_data]    |     /Users/joostbox/nltk_data...
# [nltk_data]    |   Package product_reviews_2 is already up-to-date!
# [nltk_data]    | Downloading package propbank to
# [nltk_data]    |     /Users/joostbox/nltk_data...
# [nltk_data]    |   Package propbank is already up-to-date!
# [nltk_data]    | Downloading package pros_cons to
# [nltk_data]    |     /Users/joostbox/nltk_data...
# [nltk_data]    |   Package pros_cons is already up-to-date!
# [nltk_data]    | Downloading package ptb to
# [nltk_data]    |     /Users/joostbox/nltk_data...
# [nltk_data]    |   Package ptb is already up-to-date!
# [nltk_data]    | Downloading package punkt to
# [nltk_data]    |     /Users/joostbox/nltk_data...
# [nltk_data]    |   Package punkt is already up-to-date!
# [nltk_data]    | Downloading package punkt_tab to
# [nltk_data]    |     /Users/joostbox/nltk_data...
# [nltk_data]    |   Package punkt_tab is already up-to-date!
# [nltk_data]    | Downloading package qc to
# [nltk_data]    |     /Users/joostbox/nltk_data...
# [nltk_data]    |   Package qc is already up-to-date!
# [nltk_data]    | Downloading package reuters to
# [nltk_data]    |     /Users/joostbox/nltk_data...
# [nltk_data]    |   Package reuters is already up-to-date!
# [nltk_data]    | Downloading package rslp to
# [nltk_data]    |     /Users/joostbox/nltk_data...
# [nltk_data]    |   Package rslp is already up-to-date!
# [nltk_data]    | Downloading package rte to
# [nltk_data]    |     /Users/joostbox/nltk_data...
# [nltk_data]    |   Package rte is already up-to-date!
# [nltk_data]    | Downloading package sample_grammars to
# [nltk_data]    |     /Users/joostbox/nltk_data...
# [nltk_data]    |   Package sample_grammars is already up-to-date!
# [nltk_data]    | Downloading package semcor to
# [nltk_data]    |     /Users/joostbox/nltk_data...
# [nltk_data]    |   Package semcor is already up-to-date!
# [nltk_data]    | Downloading package senseval to
# [nltk_data]    |     /Users/joostbox/nltk_data...
# [nltk_data]    |   Package senseval is already up-to-date!
# [nltk_data]    | Downloading package sentence_polarity to
# [nltk_data]    |     /Users/joostbox/nltk_data...
# [nltk_data]    |   Package sentence_polarity is already up-to-date!
# [nltk_data]    | Downloading package sentiwordnet to
# [nltk_data]    |     /Users/joostbox/nltk_data...
# [nltk_data]    |   Package sentiwordnet is already up-to-date!
# [nltk_data]    | Downloading package shakespeare to
# [nltk_data]    |     /Users/joostbox/nltk_data...
# [nltk_data]    |   Package shakespeare is already up-to-date!
# [nltk_data]    | Downloading package sinica_treebank to
# [nltk_data]    |     /Users/joostbox/nltk_data...
# [nltk_data]    |   Package sinica_treebank is already up-to-date!
# [nltk_data]    | Downloading package smultron to
# [nltk_data]    |     /Users/joostbox/nltk_data...
# [nltk_data]    |   Package smultron is already up-to-date!
# [nltk_data]    | Downloading package snowball_data to
# [nltk_data]    |     /Users/joostbox/nltk_data...
# [nltk_data]    |   Package snowball_data is already up-to-date!
# [nltk_data]    | Downloading package spanish_grammars to
# [nltk_data]    |     /Users/joostbox/nltk_data...
# [nltk_data]    |   Package spanish_grammars is already up-to-date!
# [nltk_data]    | Downloading package state_union to
# [nltk_data]    |     /Users/joostbox/nltk_data...
# [nltk_data]    |   Package state_union is already up-to-date!
# [nltk_data]    | Downloading package stopwords to
# [nltk_data]    |     /Users/joostbox/nltk_data...
# [nltk_data]    |   Package stopwords is already up-to-date!
# [nltk_data]    | Downloading package subjectivity to
# [nltk_data]    |     /Users/joostbox/nltk_data...
# [nltk_data]    |   Package subjectivity is already up-to-date!
# [nltk_data]    | Downloading package swadesh to
# [nltk_data]    |     /Users/joostbox/nltk_data...
# [nltk_data]    |   Package swadesh is already up-to-date!
# [nltk_data]    | Downloading package switchboard to
# [nltk_data]    |     /Users/joostbox/nltk_data...
# [nltk_data]    |   Package switchboard is already up-to-date!
# [nltk_data]    | Downloading package tagsets to
# [nltk_data]    |     /Users/joostbox/nltk_data...
# [nltk_data]    |   Package tagsets is already up-to-date!
# [nltk_data]    | Downloading package tagsets_json to
# [nltk_data]    |     /Users/joostbox/nltk_data...
# [nltk_data]    |   Package tagsets_json is already up-to-date!
# [nltk_data]    | Downloading package timit to
# [nltk_data]    |     /Users/joostbox/nltk_data...
# [nltk_data]    |   Package timit is already up-to-date!
# [nltk_data]    | Downloading package toolbox to
# [nltk_data]    |     /Users/joostbox/nltk_data...
# [nltk_data]    |   Package toolbox is already up-to-date!
# [nltk_data]    | Downloading package treebank to
# [nltk_data]    |     /Users/joostbox/nltk_data...
# [nltk_data]    |   Package treebank is already up-to-date!
# [nltk_data]    | Downloading package twitter_samples to
# [nltk_data]    |     /Users/joostbox/nltk_data...
# [nltk_data]    |   Package twitter_samples is already up-to-date!
# [nltk_data]    | Downloading package udhr to
# [nltk_data]    |     /Users/joostbox/nltk_data...
# [nltk_data]    |   Package udhr is already up-to-date!
# [nltk_data]    | Downloading package udhr2 to
# [nltk_data]    |     /Users/joostbox/nltk_data...
# [nltk_data]    |   Package udhr2 is already up-to-date!
# [nltk_data]    | Downloading package unicode_samples to
# [nltk_data]    |     /Users/joostbox/nltk_data...
# [nltk_data]    |   Package unicode_samples is already up-to-date!
# [nltk_data]    | Downloading package universal_tagset to
# [nltk_data]    |     /Users/joostbox/nltk_data...
# [nltk_data]    |   Package universal_tagset is already up-to-date!
# [nltk_data]    | Downloading package universal_treebanks_v20 to
# [nltk_data]    |     /Users/joostbox/nltk_data...
# [nltk_data]    |   Package universal_treebanks_v20 is already up-to-
# [nltk_data]    |       date!
# [nltk_data]    | Downloading package vader_lexicon to
# [nltk_data]    |     /Users/joostbox/nltk_data...
# [nltk_data]    |   Package vader_lexicon is already up-to-date!
# [nltk_data]    | Downloading package verbnet to
# [nltk_data]    |     /Users/joostbox/nltk_data...
# [nltk_data]    |   Package verbnet is already up-to-date!
# [nltk_data]    | Downloading package verbnet3 to
# [nltk_data]    |     /Users/joostbox/nltk_data...
# [nltk_data]    |   Package verbnet3 is already up-to-date!
# [nltk_data]    | Downloading package webtext to
# [nltk_data]    |     /Users/joostbox/nltk_data...
# [nltk_data]    |   Package webtext is already up-to-date!
# [nltk_data]    | Downloading package wmt15_eval to
# [nltk_data]    |     /Users/joostbox/nltk_data...
# [nltk_data]    |   Package wmt15_eval is already up-to-date!
# [nltk_data]    | Downloading package word2vec_sample to
# [nltk_data]    |     /Users/joostbox/nltk_data...
# [nltk_data]    |   Package word2vec_sample is already up-to-date!
# [nltk_data]    | Downloading package wordnet to
# [nltk_data]    |     /Users/joostbox/nltk_data...
# [nltk_data]    |   Package wordnet is already up-to-date!
# [nltk_data]    | Downloading package wordnet2021 to
# [nltk_data]    |     /Users/joostbox/nltk_data...
# [nltk_data]    |   Package wordnet2021 is already up-to-date!
# [nltk_data]    | Downloading package wordnet2022 to
# [nltk_data]    |     /Users/joostbox/nltk_data...
# [nltk_data]    |   Package wordnet2022 is already up-to-date!
# [nltk_data]    | Downloading package wordnet31 to
# [nltk_data]    |     /Users/joostbox/nltk_data...
# [nltk_data]    |   Package wordnet31 is already up-to-date!
# [nltk_data]    | Downloading package wordnet_ic to
# [nltk_data]    |     /Users/joostbox/nltk_data...
# [nltk_data]    |   Package wordnet_ic is already up-to-date!
# [nltk_data]    | Downloading package words to
# [nltk_data]    |     /Users/joostbox/nltk_data...
# [nltk_data]    |   Package words is already up-to-date!
# [nltk_data]    | Downloading package ycoe to
# [nltk_data]    |     /Users/joostbox/nltk_data...
# [nltk_data]    |   Package ycoe is already up-to-date!
# [nltk_data]    |
# [nltk_data]  Done downloading collection all
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/joostbox/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/joostbox/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/joostbox/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
# Set Pandas truncation of long strings
pd.set_option('display.max_colwidth', 1000)

# %% [markdown]
# ### Import Data

# %%
data_sentiment = pd.read_csv('Datasets/ukrainerussian_tweets.csv')

# %% [markdown]
# ### Explanation on what we are looking out for:
# * What are we trying to tackle?
#   *  Indulge in such a topic where we analyse the emotions of the general public as tensions
# continued to arise between Russian and Ukraine supporters. Therefore, we are doing sentiment analysis on
# the Ukraine-Russia War on Twitter.
# * Objectives:
#   * Identify the mental state of the general public based on the comments extracted from the tweets on Twitter
#   * Understand how this conflict has affected the general public using sentiment analysis
#   * Data Source: https://www.kaggle.com/datasets/towhidultonmoy/russia-vs-ukraine-tweets-datasetdaily-updated
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Inspect the data & Explore Data

# %%
# Retrieve all the columns within the dataframe
data_sentiment.columns
# Out:
# Index(['id', 'conversation_id', 'created_at', 'date', 'time', 'timezone',
#        'user_id', 'username', 'name', 'place', 'tweet', 'language', 'mentions',
#        'urls', 'photos', 'replies_count', 'retweets_count', 'likes_count',
#        'hashtags', 'cashtags', 'link', 'retweet', 'quote_url', 'video',
#        'thumbnail', 'near', 'geo', 'source', 'user_rt_id', 'user_rt',
#        'retweet_id', 'reply_to', 'retweet_date', 'translate', 'trans_src',
#        'trans_dest'],
#       dtype='object')

# %%
# View the trpes of data collected in each column of the data frame
data_sentiment.dtypes
# Out:
# id                   int64
# conversation_id      int64
# created_at          object
# date                object
# time                object
# timezone             int64
# user_id              int64
# username            object
# name                object
# place               object
# tweet               object
# language            object
# mentions            object
# urls                object
# photos              object
# replies_count        int64
# retweets_count       int64
# likes_count          int64
# hashtags            object
# cashtags            object
# link                object
# retweet               bool
# quote_url           object
# video                int64
# thumbnail           object
# near               float64
# geo                float64
# source             float64
# user_rt_id         float64
# user_rt            float64
# retweet_id         float64
# reply_to            object
# retweet_date       float64
# translate          float64
# trans_src          float64
# trans_dest         float64
# dtype: object

# %%
# The main set of data we will be preprocessing for detecting emotions -> Tweet column
data_sentiment['tweet']
# Out:
# 0                                                                                                                @jensstoltenberg Nato/otan is the most terrorist organization in the world , there members are only white. The unipolar way is over now is multi     and russia and china are the new order
# 1                                                                                                                     @bjovan3 @KimDotcom You’re talking as if it was Ukraine that invaded Russia and was trying to seize the capital. Are you sure you’re not confusing the two countries with one another?
# 2                                                                                                                                                                                                                                       @Trollstoy88 Bet russia wishes it hadnt wasted them all in syria now
# 3                                                                                                              On the last meeting Lukashenko and Putin talking about respect thst west should respect us then we can negotiate (here we have Stoltenberg show respect to Russia:)   https://t.co/e0ptJTwh6g
# 4                                                                                                                                                                                        @hrkbenowen Why wouldn't he be? Russia (not that I'm a #putinpuppet) ain't playin' out here! Steamroll Season#7...😉
#                                                                                                                                                         ...
# 10004                                                                                                                                                                                                                 Ukraine has won the war. Russia is leaving Ukraine after heavy losses and humiliation.
# 10005                                                                                                                    Biden says it remains to be seen if the Kherson withdrawal will lead to some "recalibration of positions" over the winter and if Ukraine will be willing to compromise with Russia.
# 10006                                                                                                                                                                               Talks with Russia? No way, say Ukrainians | Russia-Ukraine war News | Al Jazeera  https://t.co/L6Eh1ps5SF via @AJEnglish
# 10007                                                                                                                                                                                @DylanBurns1776 Supporting kurds to sow division in Iran and Syria and Iraq is ok since it's not Russia that's doing it
# 10008    @Breaking911 I voted for him last time, can’t say I’m up for 4 more years of Dems hollering Russia, and billions on stupid impeachments. And trashing your own people that supported you, not appealing at all. I can get the same policies, without the mouth from DeSantis. I’ll go with desantis
# Name: tweet, Length: 10009, dtype: object

# %%
# Extracting columns required to perform sentiment analysis
df_tweets1 = pd.DataFrame({'tweet': pd.Series(data_sentiment['tweet']),
                           'language': pd.Series(data_sentiment['language'])})

# %%
df_tweets = data_sentiment[['tweet', 'language']]

# %%
df_tweets.equals(df_tweets1)
# Out:
# True

# %% [markdown]
# ### EDA

# %%
df_tweets.head()
# Out:
#                                                                                                                                                                                            tweet  \
# 0    @jensstoltenberg Nato/otan is the most terrorist organization in the world , there members are only white. The unipolar way is over now is multi     and russia and china are the new order
# 1         @bjovan3 @KimDotcom You’re talking as if it was Ukraine that invaded Russia and was trying to seize the capital. Are you sure you’re not confusing the two countries with one another?
# 2                                                                                                                           @Trollstoy88 Bet russia wishes it hadnt wasted them all in syria now
# 3  On the last meeting Lukashenko and Putin talking about respect thst west should respect us then we can negotiate (here we have Stoltenberg show respect to Russia:)   https://t.co/e0ptJTwh6g
# 4                                                                            @hrkbenowen Why wouldn't he be? Russia (not that I'm a #putinpuppet) ain't playin' out here! Steamroll Season#7...😉
#
#   language
# 0       en
# 1       en
# 2       en
# 3       en
# 4       en

# %% [markdown]
# ### Plot a bar graph to show the distribution of the top 5 languages reflected in the twitter dataset

# %%
# Printing out unique row data in the langauge column
print(df_tweets['language'].unique())
# Out:
# ['en' 'qme' 'pt' 'nl' 'it' 'ca' 'in' 'und' 'ta' 'ja' 'fr' 'zh' 'vi' 'ro'
#  'th' 'de' 'ht' 'es' 'qht' 'ur' 'ru' 'fi' 'ar' 'cs' 'pl' 'hi' 'tl' 'tr'
#  'no' 'et' 'uk' 'el' 'da' 'qam' 'iw' 'sv' 'lt' 'bg']

# %%
# Counting the number of each language type using value_counts() function
df_tweets['language'].value_counts()
# Out:
# language
# en     8793
# pt      343
# it      232
# qme     138
# und      80
# in       54
# th       53
# es       38
# vi       37
# ru       36
# ca       34
# de       27
# ja       26
# fr       25
# nl       13
# ar       11
# qht       9
# fi        8
# pl        6
# ro        5
# zh        5
# et        4
# cs        4
# uk        4
# hi        4
# tl        4
# no        2
# ht        2
# tr        2
# qam       2
# lt        1
# sv        1
# iw        1
# ur        1
# da        1
# el        1
# ta        1
# bg        1
# Name: count, dtype: int64

# %%
df_tweets['language'].value_counts()[0:5].plot(kind= 'bar')
# Out:
# <Axes: xlabel='language'>

# %%
# Choosing top 5 language

# %%
# Plotting the Bar Graph
# Setting theme for the sns background
sns.set_theme(style='darkgrid')
# Plot bar graph using barplot() function
sns.barplot(x=top5_lang.index , y =top5_lang.values )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[229], line 5
#       3 sns.set_theme(style='darkgrid')
#       4 # Plot bar graph using barplot() function
# ----> 5 sns.barplot(x=top5_lang.index , y =top5_lang.values )
#
# NameError: name 'top5_lang' is not defined

# %% [markdown]
# ### Data Cleaning
# We will now be taking the tweet data that are in english language

# %%
en_tweets = df_tweets.query('language == "en"').reset_index()

# %%
en_tweets
# Out:
#       index  \
# 0         0
# 1         1
# 2         2
# 3         3
# 4         4
# ...     ...
# 8788  10004
# 8789  10005
# 8790  10006
# 8791  10007
# 8792  10008
#
#                                                                                                                                                                                                                                                                                                     tweet  \
# 0                                                                                                             @jensstoltenberg Nato/otan is the most terrorist organization in the world , there members are only white. The unipolar way is over now is multi     and russia and china are the new order
# 1                                                                                                                  @bjovan3 @KimDotcom You’re talking as if it was Ukraine that invaded Russia and was trying to seize the capital. Are you sure you’re not confusing the two countries with one another?
# 2                                                                                                                                                                                                                                    @Trollstoy88 Bet russia wishes it hadnt wasted them all in syria now
# 3                                                                                                           On the last meeting Lukashenko and Putin talking about respect thst west should respect us then we can negotiate (here we have Stoltenberg show respect to Russia:)   https://t.co/e0ptJTwh6g
# 4                                                                                                                                                                                     @hrkbenowen Why wouldn't he be? Russia (not that I'm a #putinpuppet) ain't playin' out here! Steamroll Season#7...😉
# ...                                                                                                                                                                                                                                                                                                   ...
# 8788                                                                                                                                                                                                               Ukraine has won the war. Russia is leaving Ukraine after heavy losses and humiliation.
# 8789                                                                                                                  Biden says it remains to be seen if the Kherson withdrawal will lead to some "recalibration of positions" over the winter and if Ukraine will be willing to compromise with Russia.
# 8790                                                                                                                                                                             Talks with Russia? No way, say Ukrainians | Russia-Ukraine war News | Al Jazeera  https://t.co/L6Eh1ps5SF via @AJEnglish
# 8791                                                                                                                                                                              @DylanBurns1776 Supporting kurds to sow division in Iran and Syria and Iraq is ok since it's not Russia that's doing it
# 8792  @Breaking911 I voted for him last time, can’t say I’m up for 4 more years of Dems hollering Russia, and billions on stupid impeachments. And trashing your own people that supported you, not appealing at all. I can get the same policies, without the mouth from DeSantis. I’ll go with desantis
#
#      language
# 0          en
# 1          en
# 2          en
# 3          en
# 4          en
# ...       ...
# 8788       en
# 8789       en
# 8790       en
# 8791       en
# 8792       en
#
# [8793 rows x 3 columns]

# %%
# Setting lemmatize and stopword variable
lemmatizer = WordNetLemmatizer()
stopword = set(stopwords.words('english'))

# %%
# Processing Tweet data
def tweet_processor(tweet_data):
  tweet_data = tweet_data.lower()
  # Removes any content that is in the format is "[example_text]"
  tweet_data = re.sub('\[.*?\]', '', tweet_data)
  # Remove any text that is not lowercased
  tweet_data = re.sub("[^a-z\s]", "", tweet_data)
  return(tweet_data)

# %%
# Apply the tweet_processor to the first row
df_tweets['tweet'][:1].apply(tweet_processor)
# Out:
# 0    jensstoltenberg natootan is the most terrorist organization in the world  there members are only white the unipolar way is over now is multi     and russia and china are the new order
# Name: tweet, dtype: object

# %%
# Processing Tweet data in more detail
def tweet_processor(tweet_data):
  # Changing all tweet texts to be lowercase
  tweet_data = tweet_data.lower()

  # Removing punctuation
  tweet_data = re.sub('\[.*?\]', '', tweet_data)

  # Removing special characters and numbers
  tweet_data = re.sub("[^a-z\s]", "", tweet_data)

  # Removing hashtags
  tweet_data = re.sub("#", " ", tweet_data)

  # Removing RT
  tweet_data = re.sub("RT[\s]+", "", tweet_data)

  # Removing hyperlinks
  tweet_data = re.sub('https?://\S+|www\.\S+', '', tweet_data)

  tweet_data = re.sub('<.*?>+', '', tweet_data)

  tweet_data = re.sub('[%s]' % re.escape(string.punctuation), '', tweet_data)

  # Removing lines separated by \n
  tweet_data = re.sub('\n', '', tweet_data)

  # Removing usernames
  tweet_data = re.sub('\w*\d\w*', '', tweet_data)

  # Removing stopwords
  tweet_data = [word for word in tweet_data.split(' ') if word not in stopword]
  tweet_data = " ".join(tweet_data)

  # Lemmatisation
  tweet_data = [lemmatizer.lemmatize(word) for word in tweet_data.split(' ')]
  tweet_data = " ".join(tweet_data)
  # tweet_data = ",".join([str(i) for i in tweet_data])
  return tweet_data

# %%
# Copying dataframe and storing it in a new dataframe
processed_tweet_data = df_tweets.copy()

# %%
# Applying the tweet_processor function created
processed_tweet_data['Reviewed_Tweet'] = df_tweets['tweet'].apply(tweet_processor)

# %%
# Displaying processed tweet data
processed_tweet_data['Reviewed_Tweet']
# Out:
# 0                                                                        jensstoltenberg natootan terrorist organization world  member white unipolar way multi     russia china new order
# 1                                                                  bjovan kimdotcom youre talking ukraine invaded russia trying seize capital sure youre confusing two country one another
# 2                                                                                                                                             trollstoy bet russia wish hadnt wasted syria
# 3                                                           last meeting lukashenko putin talking respect thst west respect u negotiate stoltenberg show respect russia   httpstcoeptjtwhg
# 4                                                                                                                    hrkbenowen wouldnt russia im putinpuppet aint playin steamroll season
#                                                                                                ...
# 10004                                                                                                                            ukraine war russia leaving ukraine heavy loss humiliation
# 10005                                                                       biden say remains seen kherson withdrawal lead recalibration position winter ukraine willing compromise russia
# 10006                                                                                     talk russia way say ukrainian  russiaukraine war news  al jazeera  httpstcolehpssf via ajenglish
# 10007                                                                                                        dylanburns supporting kurd sow division iran syria iraq ok since russia thats
# 10008    breaking voted last time cant say im  year dems hollering russia billion stupid impeachment trashing people supported appealing get policy without mouth desantis ill go desantis
# Name: Reviewed_Tweet, Length: 10009, dtype: object

# %% [markdown]
# ### More EDA

# %%
# Subjectivity of the processed data from 0 to 1, 0 means neutral/facts, 1 means personal opinion
# Create a function to get the subjectivity
def getSubjectivity(text):
    return TextBlob(text).sentiment.subjectivity

# %%
# Polarity of the processed data from -1 to 1, -1 means negative, 0 means neutral, 1 means positive
# Create a function to get the polarity
def getPolarity(text):
    return TextBlob(text).sentiment.polarity

# %%
# Creating columns to display subjectivity and polarity
processed_tweet_data['Subjectivity'] = processed_tweet_data['Reviewed_Tweet'].apply(getSubjectivity)
processed_tweet_data['Polarity'] = processed_tweet_data['Reviewed_Tweet'].apply(getPolarity)

# %%
processed_tweet_data
# Out:
#                                                                                                                                                                                                                                                                                                      tweet  \
# 0                                                                                                              @jensstoltenberg Nato/otan is the most terrorist organization in the world , there members are only white. The unipolar way is over now is multi     and russia and china are the new order
# 1                                                                                                                   @bjovan3 @KimDotcom You’re talking as if it was Ukraine that invaded Russia and was trying to seize the capital. Are you sure you’re not confusing the two countries with one another?
# 2                                                                                                                                                                                                                                     @Trollstoy88 Bet russia wishes it hadnt wasted them all in syria now
# 3                                                                                                            On the last meeting Lukashenko and Putin talking about respect thst west should respect us then we can negotiate (here we have Stoltenberg show respect to Russia:)   https://t.co/e0ptJTwh6g
# 4                                                                                                                                                                                      @hrkbenowen Why wouldn't he be? Russia (not that I'm a #putinpuppet) ain't playin' out here! Steamroll Season#7...😉
# ...                                                                                                                                                                                                                                                                                                    ...
# 10004                                                                                                                                                                                                               Ukraine has won the war. Russia is leaving Ukraine after heavy losses and humiliation.
# 10005                                                                                                                  Biden says it remains to be seen if the Kherson withdrawal will lead to some "recalibration of positions" over the winter and if Ukraine will be willing to compromise with Russia.
# 10006                                                                                                                                                                             Talks with Russia? No way, say Ukrainians | Russia-Ukraine war News | Al Jazeera  https://t.co/L6Eh1ps5SF via @AJEnglish
# 10007                                                                                                                                                                              @DylanBurns1776 Supporting kurds to sow division in Iran and Syria and Iraq is ok since it's not Russia that's doing it
# 10008  @Breaking911 I voted for him last time, can’t say I’m up for 4 more years of Dems hollering Russia, and billions on stupid impeachments. And trashing your own people that supported you, not appealing at all. I can get the same policies, without the mouth from DeSantis. I’ll go with desantis
#
#       language  \
# 0           en
# 1           en
# 2           en
# 3           en
# 4           en
# ...        ...
# 10004       en
# 10005       en
# 10006       en
# 10007       en
# 10008       en
#
#                                                                                                                                                                           Reviewed_Tweet  \
# 0                                                                      jensstoltenberg natootan terrorist organization world  member white unipolar way multi     russia china new order
# 1                                                                bjovan kimdotcom youre talking ukraine invaded russia trying seize capital sure youre confusing two country one another
# 2                                                                                                                                           trollstoy bet russia wish hadnt wasted syria
# 3                                                         last meeting lukashenko putin talking respect thst west respect u negotiate stoltenberg show respect russia   httpstcoeptjtwhg
# 4                                                                                                                  hrkbenowen wouldnt russia im putinpuppet aint playin steamroll season
# ...                                                                                                                                                                                  ...
# 10004                                                                                                                          ukraine war russia leaving ukraine heavy loss humiliation
# 10005                                                                     biden say remains seen kherson withdrawal lead recalibration position winter ukraine willing compromise russia
# 10006                                                                                   talk russia way say ukrainian  russiaukraine war news  al jazeera  httpstcolehpssf via ajenglish
# 10007                                                                                                      dylanburns supporting kurd sow division iran syria iraq ok since russia thats
# 10008  breaking voted last time cant say im  year dems hollering russia billion stupid impeachment trashing people supported appealing get policy without mouth desantis ill go desantis
#
#        Subjectivity  Polarity
# 0          0.227273  0.068182
# 1          0.644444  0.100000
# 2          0.000000 -0.200000
# 3          0.066667  0.000000
# 4          0.000000  0.000000
# ...             ...       ...
# 10004      0.500000 -0.200000
# 10005      0.750000  0.250000
# 10006      0.000000  0.000000
# 10007      0.375000  0.375000
# 10008      0.641667 -0.200000
#
# [10009 rows x 5 columns]

# %% [markdown]
# ### Word Cloud

# %%
allTweets = ' '.join([tweets for tweets in processed_tweet_data['Reviewed_Tweet']])
RU_wordcloud=WordCloud(width=900, height=600, random_state=21, max_font_size=100).generate(allTweets)
plt.imshow(RU_wordcloud, interpolation = 'bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# ### Computing negative, neutral and positive analysis

# %%
def getComputation(score):
    if score < -0.5:
        return "very negative"
    if score < 0:
        return "negative"
    if score == 0:
        return "neutral"
    if score > 0:
        return "positive"
    if score > 0.5:
        return "very positive"
processed_tweet_data['computation_analysis'] = processed_tweet_data['Polarity'].apply(getComputation)

# %%
processed_tweet_data
# Out:
#                                                                                                                                                                                                                                                                                                      tweet  \
# 0                                                                                                              @jensstoltenberg Nato/otan is the most terrorist organization in the world , there members are only white. The unipolar way is over now is multi     and russia and china are the new order
# 1                                                                                                                   @bjovan3 @KimDotcom You’re talking as if it was Ukraine that invaded Russia and was trying to seize the capital. Are you sure you’re not confusing the two countries with one another?
# 2                                                                                                                                                                                                                                     @Trollstoy88 Bet russia wishes it hadnt wasted them all in syria now
# 3                                                                                                            On the last meeting Lukashenko and Putin talking about respect thst west should respect us then we can negotiate (here we have Stoltenberg show respect to Russia:)   https://t.co/e0ptJTwh6g
# 4                                                                                                                                                                                      @hrkbenowen Why wouldn't he be? Russia (not that I'm a #putinpuppet) ain't playin' out here! Steamroll Season#7...😉
# ...                                                                                                                                                                                                                                                                                                    ...
# 10004                                                                                                                                                                                                               Ukraine has won the war. Russia is leaving Ukraine after heavy losses and humiliation.
# 10005                                                                                                                  Biden says it remains to be seen if the Kherson withdrawal will lead to some "recalibration of positions" over the winter and if Ukraine will be willing to compromise with Russia.
# 10006                                                                                                                                                                             Talks with Russia? No way, say Ukrainians | Russia-Ukraine war News | Al Jazeera  https://t.co/L6Eh1ps5SF via @AJEnglish
# 10007                                                                                                                                                                              @DylanBurns1776 Supporting kurds to sow division in Iran and Syria and Iraq is ok since it's not Russia that's doing it
# 10008  @Breaking911 I voted for him last time, can’t say I’m up for 4 more years of Dems hollering Russia, and billions on stupid impeachments. And trashing your own people that supported you, not appealing at all. I can get the same policies, without the mouth from DeSantis. I’ll go with desantis
#
#       language  \
# 0           en
# 1           en
# 2           en
# 3           en
# 4           en
# ...        ...
# 10004       en
# 10005       en
# 10006       en
# 10007       en
# 10008       en
#
#                                                                                                                                                                           Reviewed_Tweet  \
# 0                                                                      jensstoltenberg natootan terrorist organization world  member white unipolar way multi     russia china new order
# 1                                                                bjovan kimdotcom youre talking ukraine invaded russia trying seize capital sure youre confusing two country one another
# 2                                                                                                                                           trollstoy bet russia wish hadnt wasted syria
# 3                                                         last meeting lukashenko putin talking respect thst west respect u negotiate stoltenberg show respect russia   httpstcoeptjtwhg
# 4                                                                                                                  hrkbenowen wouldnt russia im putinpuppet aint playin steamroll season
# ...                                                                                                                                                                                  ...
# 10004                                                                                                                          ukraine war russia leaving ukraine heavy loss humiliation
# 10005                                                                     biden say remains seen kherson withdrawal lead recalibration position winter ukraine willing compromise russia
# 10006                                                                                   talk russia way say ukrainian  russiaukraine war news  al jazeera  httpstcolehpssf via ajenglish
# 10007                                                                                                      dylanburns supporting kurd sow division iran syria iraq ok since russia thats
# 10008  breaking voted last time cant say im  year dems hollering russia billion stupid impeachment trashing people supported appealing get policy without mouth desantis ill go desantis
#
#        Subjectivity  Polarity computation_analysis
# 0          0.227273  0.068182             positive
# 1          0.644444  0.100000             positive
# 2          0.000000 -0.200000             negative
# 3          0.066667  0.000000              neutral
# 4          0.000000  0.000000              neutral
# ...             ...       ...                  ...
# 10004      0.500000 -0.200000             negative
# 10005      0.750000  0.250000             positive
# 10006      0.000000  0.000000              neutral
# 10007      0.375000  0.375000             positive
# 10008      0.641667 -0.200000             negative
#
# [10009 rows x 6 columns]

# %%
processed_tweet_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10009 entries, 0 to 10008
# Data columns (total 6 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   tweet                 10009 non-null  object
#  1   language              10009 non-null  object
#  2   Reviewed_Tweet        10009 non-null  object
#  3   Subjectivity          10009 non-null  float64
#  4   Polarity              10009 non-null  float64
#  5   computation_analysis  10009 non-null  object
# dtypes: float64(2), object(4)
# memory usage: 469.3+ KB

# %% [markdown]
# ### Plotting Polarity and Subjectivity
# Polarity of the processed data - Ranges from -1 to 1; -1 means negative, 0 means neutral, 1 means positive <br>
# Subjectivity of processed data - Ranges from 0 to 1; 0 means neutral/facts, 1 means personal opinion

# %%
# Creating a new dataframe sort_data to sort te polarity amd computation analysis
sort_data = processed_tweet_data.sort_values(by= ['Polarity'])

# %%
sort_data['computation_analysis'] = sort_data[['computation_analysis']]

# %%
#Plotting our scatter plot
fig, ax = plt.subplots(figsize=(8,6))
sns.scatterplot(x='Polarity', y='Subjectivity', hue='computation_analysis', data=sort_data)
plt.show()

# %%
# Creating our variables to store each column
# !pip install plotly
import plotly.figure_factory as ff

positive = sort_data[sort_data.computation_analysis== 'Positive']
neutral = sort_data[sort_data.computation_analysis=='Neutral']
neg = sort_data[sort_data.computation_analysis=='Negative']
vneg = sort_data[sort_data.computation_analysis=='Very Negative']

# %% [markdown]
# hist_data = [positive['length'],neutral['length'] , neg['length'] , vneg['length']]
#
# group_labels = ['Positive', 'Neutral', 'Negative', 'Very Negative']
#
# colors = ['black', 'red']
#
# ### Create distplot with curve_type set to 'normal'
# fig = ff.create_distplot(hist_data, group_labels, show_hist=False)
#
# ### Add title
# fig.update_layout(title_text='Length distribution of ham and spam messages',
#                  template = 'simple_white')
# fig.show()

# %% [markdown]
# ### Computing percentage of positive, neutral and negative tweets

# %%
# Percentage of positive tweets
posTweets = sort_data[sort_data.computation_analysis=='positive']
posTweets = posTweets['Reviewed_Tweet']
round((posTweets.shape[0]/sort_data.shape[0] * 100), 1)
# Out:
# 36.0

# %%
# Percentage of neutral tweets
neuTweets = sort_data[sort_data.computation_analysis=='neutral']
neuTweets = neuTweets['Reviewed_Tweet']
round((neuTweets.shape[0]/sort_data.shape[0] * 100), 1)
# Out:
# 41.2

# %%
# Percentage of negative tweets
negTweets = sort_data[sort_data.computation_analysis=='negative']
negTweets = negTweets['Reviewed_Tweet']
round((negTweets.shape[0]/sort_data.shape[0] * 100), 1)
# Out:
# 21.0

# %%
# Percentage of very negative tweets
vnegTweets = sort_data[sort_data.computation_analysis=='very negative']
vnegTweets = vnegTweets['Reviewed_Tweet']
round((vnegTweets.shape[0]/sort_data.shape[0] * 100), 1)
# Out:
# 1.8

# %%
sort_data.computation_analysis.value_counts(normalize = True)* 100
# Out:
# computation_analysis
# neutral          41.232890
# positive         35.997602
# negative         20.951144
# very negative     1.818363
# Name: proportion, dtype: float64

# %% [markdown]
# ### Graphical Representation of Tweet Analysis

# %%
sort_data['computation_analysis'].value_counts()
plt.title('Russian vs Ukraine Sentiment Analysis')
# plt.xlabel('General Sentiment Type')
# plt.ylabel('Count')
sns.countplot(x='computation_analysis', data=sort_data)
# Out:
# <Axes: title={'center': 'Russian vs Ukraine Sentiment Analysis'}, xlabel='computation_analysis', ylabel='count'>

# %%
tags = sort_data['computation_analysis'].value_counts()

colors = {'mediumturquoise', 'limegreen', 'mediumpurple', 'red'}
explode=(0.1,0.1,0.1,0.1 )

tags.plot(kind='pie' , explode = explode , colors = colors , label = '')
plt.title('Russian VS Ukraine Sentiment Analysis')
# Out:
# Text(0.5, 1.0, 'Russian VS Ukraine Sentiment Analysis')

# %% [markdown]
# ### Emotion Detection

# %%
# Using a python library to determine the extent of the person's emotions(e.g. fear, anger, anticipation, ...)
sort_data['emotions'] = sort_data['Reviewed_Tweet'].apply(lambda x: NRCLex(x).affect_frequencies)
sort_data['emotions'].tail(15)
# Out:
# 5687                                                                                                                                      {'fear': 0.0, 'anger': 0.3333333333333333, 'anticip': 0.0, 'trust': 0.0, 'surprise': 0.0, 'positive': 0.3333333333333333, 'negative': 0.0, 'sadness': 0.3333333333333333, 'disgust': 0.0, 'joy': 0.0}
# 7293                                                                                                                                                                                   {'fear': 0.2, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.2, 'surprise': 0.0, 'positive': 0.2, 'negative': 0.2, 'sadness': 0.0, 'disgust': 0.2, 'joy': 0.0}
# 3054                                            {'fear': 0.29411764705882354, 'anger': 0.11764705882352941, 'anticip': 0.0, 'trust': 0.0, 'surprise': 0.058823529411764705, 'positive': 0.0, 'negative': 0.23529411764705882, 'sadness': 0.11764705882352941, 'disgust': 0.058823529411764705, 'joy': 0.0, 'anticipation': 0.11764705882352941}
# 8348                                                                                                                                                                                   {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.5, 'surprise': 0.0, 'positive': 0.5, 'negative': 0.0, 'sadness': 0.0, 'disgust': 0.0, 'joy': 0.0}
# 6928                                                                                                                                                                               {'fear': 0.25, 'anger': 0.25, 'anticip': 0.0, 'trust': 0.0, 'surprise': 0.0, 'positive': 0.25, 'negative': 0.25, 'sadness': 0.0, 'disgust': 0.0, 'joy': 0.0}
# 8744                                                                                                                                                                               {'fear': 0.0, 'anger': 0.25, 'anticip': 0.0, 'trust': 0.0, 'surprise': 0.0, 'positive': 0.25, 'negative': 0.25, 'sadness': 0.25, 'disgust': 0.0, 'joy': 0.0}
# 6352                                                                            {'fear': 0.0, 'anger': 0.08333333333333333, 'anticip': 0.0, 'trust': 0.25, 'surprise': 0.0, 'positive': 0.25, 'negative': 0.08333333333333333, 'sadness': 0.0, 'disgust': 0.08333333333333333, 'joy': 0.08333333333333333, 'anticipation': 0.16666666666666666}
# 5985                                                                                                                                      {'fear': 0.3333333333333333, 'anger': 0.3333333333333333, 'anticip': 0.0, 'trust': 0.0, 'surprise': 0.0, 'positive': 0.0, 'negative': 0.3333333333333333, 'sadness': 0.0, 'disgust': 0.0, 'joy': 0.0}
# 8328    {'fear': 0.05555555555555555, 'anger': 0.1111111111111111, 'anticip': 0.0, 'trust': 0.1111111111111111, 'surprise': 0.05555555555555555, 'positive': 0.1111111111111111, 'negative': 0.1111111111111111, 'sadness': 0.1111111111111111, 'disgust': 0.05555555555555555, 'joy': 0.1111111111111111, 'anticipation': 0.16666666666666666}
# 1437                                                                                                                                                                                   {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.0, 'surprise': 0.0, 'positive': 0.0, 'negative': 0.0, 'sadness': 0.0, 'disgust': 0.0, 'joy': 0.0}
# 1447                                                                                                                                                                                   {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.0, 'surprise': 0.0, 'positive': 0.0, 'negative': 0.0, 'sadness': 0.0, 'disgust': 0.0, 'joy': 0.0}
# 6288                                                                            {'fear': 0.0, 'anger': 0.08333333333333333, 'anticip': 0.0, 'trust': 0.25, 'surprise': 0.0, 'positive': 0.25, 'negative': 0.08333333333333333, 'sadness': 0.0, 'disgust': 0.08333333333333333, 'joy': 0.08333333333333333, 'anticipation': 0.16666666666666666}
# 8081                                                                                                                                                                                   {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.0, 'surprise': 0.0, 'positive': 1.0, 'negative': 0.0, 'sadness': 0.0, 'disgust': 0.0, 'joy': 0.0}
# 5033                                                                                                                                                                                   {'fear': 0.0, 'anger': 0.0, 'anticip': 0.0, 'trust': 0.0, 'surprise': 0.0, 'positive': 1.0, 'negative': 0.0, 'sadness': 0.0, 'disgust': 0.0, 'joy': 0.0}
# 8620                                                                                                                                                                            {'fear': 0.0, 'anger': 0.25, 'anticip': 0.0, 'trust': 0.0, 'surprise': 0.0, 'positive': 0.125, 'negative': 0.25, 'sadness': 0.25, 'disgust': 0.0, 'joy': 0.125}
# Name: emotions, dtype: object

# %%
# Removing column with emotions and the extent in dictionaries, extracting the type of emotions from the dictionary,
# concatenating as different columns into sort_data dataframe
sort_data = pd.concat([sort_data.drop(['emotions'], axis=1), sort_data['emotions'].apply(pd.Series)], axis=1)

# %%
sort_data.head()
# Out:
#                                                                                                                                                                                                                                 tweet  \
# 5482  @BahatiAllyLane @KyivIndependent For the record, in the metaphor, the dying whale is Russia. I'd say bear, but remoras are fish and the metaphor would be lost.  Maybe a tick, on a bear, that's about to die a terrible death.
# 3952                                                                                                                                      @historyinmemes North Korea, China and Russia are the evilest and most disgusting counties.
# 8128                                                                                                                                @mfa_russia @MFABulgaria @4thBgPresident @RusEmbBul @RusMission_EU @EUinRussia @RF_OSCE Pathetic!
# 8557                                                                                                                                         @Pontifex We pray for victory of Ukraine over the forces of evil, that come from Russia.
# 8011                                                                                                                                   Did Russia deliberately choose a Dr Evil lookalike to run their war?!  https://t.co/dxqf6F1y5a
#
#      language  \
# 5482       en
# 3952       en
# 8128       en
# 8557       en
# 8011       en
#
#                                                                                                                                                Reviewed_Tweet  \
# 5482  bahatiallylane kyivindependent record metaphor dying whale russia id say bear remora fish metaphor would lost  maybe tick bear thats die terrible death
# 3952                                                                                        historyinmemes north korea china russia evilest disgusting county
# 8128                                                                    mfarussia mfabulgaria thbgpresident rusembbul rusmissioneu euinrussia rfosce pathetic
# 8557                                                                                                     pontifex pray victory ukraine force evil come russia
# 8011                                                                                    russia deliberately choose dr evil lookalike run war  httpstcodxqffya
#
#       Subjectivity  Polarity computation_analysis      fear     anger  \
# 5482           1.0      -1.0        very negative  0.230769  0.192308
# 3952           1.0      -1.0        very negative  0.200000  0.200000
# 8128           1.0      -1.0        very negative  0.000000  0.000000
# 8557           1.0      -1.0        very negative  0.166667  0.111111
# 8011           1.0      -1.0        very negative  0.285714  0.142857
#
#       anticip     trust  surprise  positive  negative   sadness   disgust  \
# 5482      0.0  0.000000  0.038462  0.000000  0.192308  0.192308  0.115385
# 3952      0.0  0.200000  0.000000  0.000000  0.200000  0.000000  0.200000
# 8128      0.0  0.000000  0.000000  0.000000  0.333333  0.333333  0.333333
# 8557      0.0  0.111111  0.055556  0.111111  0.111111  0.055556  0.055556
# 8011      0.0  0.000000  0.000000  0.000000  0.285714  0.142857  0.142857
#
#            joy  anticipation
# 5482  0.000000      0.038462
# 3952  0.000000           NaN
# 8128  0.000000           NaN
# 8557  0.111111      0.111111
# 8011  0.000000           NaN

# %% [markdown]
# ### Data cleaning for the new rows added

# %%
# Checking for null values
sort_data.isnull().sum()
# Out:
# tweet                      0
# language                   0
# Reviewed_Tweet             0
# Subjectivity               0
# Polarity                   0
# computation_analysis       0
# fear                       0
# anger                      0
# anticip                    0
# trust                      0
# surprise                   0
# positive                   0
# negative                   0
# sadness                    0
# disgust                    0
# joy                        0
# anticipation            6313
# dtype: int64

# %% [markdown]
# ### Addressing null values and irrelevant columns

# %%
# Dropping irrelevant data column -> anticip
#Thsi way is not the actual correct way
sort_data.drop('anticip', axis=1, inplace=True)

# %%
# Checking the columns in sort_data
sort_data.columns
# Out:
# Index(['tweet', 'language', 'Reviewed_Tweet', 'Subjectivity', 'Polarity',
#        'computation_analysis', 'fear', 'anger', 'trust', 'surprise',
#        'positive', 'negative', 'sadness', 'disgust', 'joy', 'anticipation'],
#       dtype='object')

# %%
# Taking care of null values in anticipation
sort_data.isnull().sum()
# Out:
# tweet                      0
# language                   0
# Reviewed_Tweet             0
# Subjectivity               0
# Polarity                   0
# computation_analysis       0
# fear                       0
# anger                      0
# trust                      0
# surprise                   0
# positive                   0
# negative                   0
# sadness                    0
# disgust                    0
# joy                        0
# anticipation            6313
# dtype: int64

# %%
# Confirming that there are no null values
sort_data.head()
# Out:
#                                                                                                                                                                                                                                 tweet  \
# 5482  @BahatiAllyLane @KyivIndependent For the record, in the metaphor, the dying whale is Russia. I'd say bear, but remoras are fish and the metaphor would be lost.  Maybe a tick, on a bear, that's about to die a terrible death.
# 3952                                                                                                                                      @historyinmemes North Korea, China and Russia are the evilest and most disgusting counties.
# 8128                                                                                                                                @mfa_russia @MFABulgaria @4thBgPresident @RusEmbBul @RusMission_EU @EUinRussia @RF_OSCE Pathetic!
# 8557                                                                                                                                         @Pontifex We pray for victory of Ukraine over the forces of evil, that come from Russia.
# 8011                                                                                                                                   Did Russia deliberately choose a Dr Evil lookalike to run their war?!  https://t.co/dxqf6F1y5a
#
#      language  \
# 5482       en
# 3952       en
# 8128       en
# 8557       en
# 8011       en
#
#                                                                                                                                                Reviewed_Tweet  \
# 5482  bahatiallylane kyivindependent record metaphor dying whale russia id say bear remora fish metaphor would lost  maybe tick bear thats die terrible death
# 3952                                                                                        historyinmemes north korea china russia evilest disgusting county
# 8128                                                                    mfarussia mfabulgaria thbgpresident rusembbul rusmissioneu euinrussia rfosce pathetic
# 8557                                                                                                     pontifex pray victory ukraine force evil come russia
# 8011                                                                                    russia deliberately choose dr evil lookalike run war  httpstcodxqffya
#
#       Subjectivity  Polarity computation_analysis      fear     anger  \
# 5482           1.0      -1.0        very negative  0.230769  0.192308
# 3952           1.0      -1.0        very negative  0.200000  0.200000
# 8128           1.0      -1.0        very negative  0.000000  0.000000
# 8557           1.0      -1.0        very negative  0.166667  0.111111
# 8011           1.0      -1.0        very negative  0.285714  0.142857
#
#          trust  surprise  positive  negative   sadness   disgust       joy  \
# 5482  0.000000  0.038462  0.000000  0.192308  0.192308  0.115385  0.000000
# 3952  0.200000  0.000000  0.000000  0.200000  0.000000  0.200000  0.000000
# 8128  0.000000  0.000000  0.000000  0.333333  0.333333  0.333333  0.000000
# 8557  0.111111  0.055556  0.111111  0.111111  0.055556  0.055556  0.111111
# 8011  0.000000  0.000000  0.000000  0.285714  0.142857  0.142857  0.000000
#
#       anticipation
# 5482      0.038462
# 3952           NaN
# 8128           NaN
# 8557      0.111111
# 8011           NaN

# %%
# Overview of dataframe

# %% [markdown]
# ### Measuring the Correlation between the features

# %%
# Plot a correlation matrix
corr_matrix = sort_data.corr(numeric_only=True)
fig,ax = plt.subplots(figsize=(12,12))
sns.heatmap(corr_matrix, annot=True)
plt.show()

# %% [markdown]
# #### Is there any correlation? What does our heatmap mean?
